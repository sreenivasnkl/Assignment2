# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Scipy:
# #We have the min and max temperatures in a city In India for each months of the year.
# #We would like to find a function to describe this and show it graphically, the dataset
# #given below.
# #Task:
# #1.fitting it to the periodic function
# #2.plot the fit

# %%
temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19,17, 18])
months = np.arange(12)
days = np.linspace(0, 12, 365)

def year_temp(times,avg,ampl,time_offset):
    return(avg + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(year_temp, months, temp_max, [20, 10, 0])
res_min, cov_min = optimize.curve_fit(year_temp, months, temp_min, [-40, 20, 0])


plt.plot(months, temp_max , 'ro')
plt.plot(days, year_temp(days, *res_max), 'r-')
plt.plot(months,temp_min,'bo')
plt.plot(days, year_temp(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %% [markdown]
# # Matplotlib
# #this assignment is for visualization using Matplotlib
# #data to use
# #url = https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv

# %%
import pandas as pd

titanic = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv')

# %% [markdown]
# #Charts to plot
# #1. Create a pie chart presenting the male/female proportion

# %%
count=titanic['sex'].value_counts()
plt.pie(count.values.tolist(), labels=count.index.values.tolist(), startangle=90, autopct='%.1f%%')
plt.title('Male/Female proportion')
plt.show()

# %% [markdown]
# #2.create a scattered plot with the fare paid and the age, differ the plot color by gender

# %%
plt.scatter(titanic['age'], titanic['fare'], alpha=0.5, c=pd.factorize(titanic['sex'])[0])
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Fare paid and the Age')
plt.show()
